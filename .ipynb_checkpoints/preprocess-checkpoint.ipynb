# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data preprocessing
# The following block remove outliers, insignificant columns and correlated values from the initial file `local_global_res_13_12.csv`

# %%
data = pd.read_csv('./data/local_global_res_13_12.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36454 entries, 0 to 36453
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   36454 non-null  int64
#  1   Unnamed: 0     36010 non-null  float64
#  2   train_time     36280 non-null  float64
#  3   forecast_time  36280 non-null  float64
#  4   MAE            36280 non-null  float64
#  5   MSE            36280 non-null  float64
#  6   RMSE           36280 non-null  float64
#  7   MASE           36280 non-null  float64
#  8   RMSSE          36280 non-null  float64
#  9   MAPE           36280 non-null  float64
#  10  SMAPE          36280 non-null  float64
#  11  naming_orig    36454 non-null  object
#  12  model_name     36454 non-null  object
#  13  dataset_name   36454 non-null  object
#  14  horizon        36454 non-null  int64
#  15  split          36454 non-null  object
#  16  pred_time      0 non-null      float64
# dtypes: float64(11), int64(2), object(4)
# memory usage: 4.7+ MB

# %% [markdown]
# Let's look at the data and display the number of unique values for each column. If column contains numeric data, min and max values (excluding NaNs) are displayed also.

# %% [markdown]
# ### Duplicates and irrelevant columns handling
# First of all, we remove all the irrelevant data, duplicates nad artefacts from the dataset.

# %%
print(f'Duplicated rows amount: {data.duplicated().sum()}')
# Out:
# Duplicated rows amount: 0

# %%
data
# Out:
#        Unnamed: 0.1  Unnamed: 0  train_time  forecast_time        MAE
# 0                 0         0.0    3.812914       4.442261  18.260277  \
# 1                 1         0.0    3.485261       4.376619  28.395468
# 2                 2         0.0    3.812914       4.442261  12.825266
# 3                 3         0.0    3.485261       4.376619  26.284388
# 4                 4         0.0    3.485261       4.376619  15.145726
# ...             ...         ...         ...            ...        ...
# 36449             0         NaN  225.815618       1.806664   2.762839
# 36450             0         NaN  221.914140       1.835336   2.712137
# 36451             0         NaN  225.815618       1.806664   1.519503
# 36452             0         NaN  221.914140       1.835336   3.380999
# 36453             0         NaN  225.815618       1.806664   4.357973
#
#                MSE       RMSE      MASE     RMSSE       MAPE      SMAPE
# 0       619.323792  24.886217  0.896638  0.792087        inf  16.386864  \
# 1      1160.189331  34.061552  1.088141  0.918072  41.157335  17.157184
# 2       269.356567  16.412086  0.814535  0.757765  39.022604  13.038494
# 3      1121.348877  33.486548  0.918232  0.792925  57.078475  18.962322
# 4       429.357697  20.720948  0.663444  0.597604  21.996029  10.027625
# ...            ...        ...       ...       ...        ...        ...
# 36449    11.352131   3.369292  0.779592  0.688223  20.044580   8.785076
# 36450    16.868277   4.107101  0.679580  0.778644  29.559124  10.474208
# 36451     3.326512   1.823873  0.381234  0.345513  11.370875   5.622922
# 36452    22.316181   4.724001  0.658609  0.684295  23.539458   8.428656
# 36453    27.742617   5.267126  0.861970  0.773556  22.037254  10.565775
#
#                naming_orig                                   model_name
# 0       danish_atm_daily_5  CatBoostAutoRegressivePipelineEtna_3lags_gl  \
# 1      danish_atm_daily_84  CatBoostAutoRegressivePipelineEtna_3lags_gl
# 2      danish_atm_daily_32  CatBoostAutoRegressivePipelineEtna_3lags_gl
# 3      danish_atm_daily_25  CatBoostAutoRegressivePipelineEtna_3lags_gl
# 4       danish_atm_daily_6  CatBoostAutoRegressivePipelineEtna_3lags_gl
# ...                    ...                                          ...
# 36449               nn5_98                        DeepARTuningObjective
# 36450               nn5_99                        DeepARTuningObjective
# 36451               nn5_99                        DeepARTuningObjective
# 36452                nn5_9                        DeepARTuningObjective
# 36453                nn5_9                        DeepARTuningObjective
#
#            dataset_name  horizon       split  pred_time
# 0      danish_atm_daily       30        test        NaN
# 1      danish_atm_daily       30  validation        NaN
# 2      danish_atm_daily       30        test        NaN
# 3      danish_atm_daily       30  validation        NaN
# 4      danish_atm_daily       30  validation        NaN
# ...                 ...      ...         ...        ...
# 36449               nn5       30  validation        NaN
# 36450               nn5       30        test        NaN
# 36451               nn5       30  validation        NaN
# 36452               nn5       30        test        NaN
# 36453               nn5       30  validation        NaN
#
# [36454 rows x 17 columns]

# %%
from pandas.api.types import is_numeric_dtype

sizes = pd.DataFrame(index=data.columns, columns=['unique_values', 'min', 'max'])

for col in data.columns:
    # For each column calculate number of unique values
    sizes.loc[col]['unique_values'] = len(data[col].unique())
    if is_numeric_dtype(data[col]):
        try:
            # If data type is numeric, try to calculate min and max values,
            # excluding NaNs
            sizes.loc[col]['min'] = np.min(data[col].dropna().unique())
            sizes.loc[col]['max'] = np.max(data[col].dropna().unique())
        except:
            # If column contains only NaNs, write NaN to both columns
            sizes.loc[col][['min', 'max']] = np.nan
    else:
        # If data type isn't numeric, write N/A - Not Applicable
        sizes.loc[col][['min', 'max']] = "N/A"

sizes
# Out:
#               unique_values       min                 max
# Unnamed: 0.1          36010         0               36009
# Unnamed: 0                2       0.0                 0.0
# train_time            18633   0.00006        28655.271598
# forecast_time         17056  0.000003          189.939747
# MAE                   29656  0.027207           8756287.0
# MSE                   29666   0.00074   115030313926656.0
# RMSE                  29666  0.027207     10725218.595752
# MASE                  29711       0.0  26820764541.625977
# RMSSE                 29715       0.0  26857884266.368134
# MAPE                  23749  6.512892                 inf
# SMAPE                 28441  3.166458               100.0
# naming_orig             876       N/A                 N/A
# model_name               24       N/A                 N/A
# dataset_name              3       N/A                 N/A
# horizon                   1        30                  30
# split                     2       N/A                 N/A
# pred_time                 1       NaN                 NaN

# %% [markdown]
# As we can see, the `pred_time`, `horizon`, `split`, `Unnamed: 0` and `Unnamed: 0.1` columns can be dropped. Former three columns contain not relevant data, while two latter columns are artefacts from files concatenation.

# %%
data = data.drop(['pred_time', 'horizon', 'split', 'Unnamed: 0', 'Unnamed: 0.1'], axis=1)

# %% [markdown]
# ### Outliers handling
# Secondly, the outliers are removed. We decided, that outliers can be no more that 2.5% of the total data volume.

# %%
# Depict classes distribution histogram
fig = plt.figure(figsize=(16,4))
plt.hist(data['model_name'], bins=24)
plt.xticks(rotation=90); plt.grid()
plt.title('Model classes distribution with outliers')
plt.show()

# %% [markdown]
# Now, we will look at the remained numerical values to find anomalies using box plots.

# %%
# Depict time metrics boxplots
times = ['train_time', 'forecast_time']
rows = 1

fig, axes = plt.subplots(nrows=rows, ncols=len(times)//rows, figsize=(16, 4))

for ax, time in zip(axes.flatten(), times):
    sns.boxplot(data[time], ax=ax, orient='h')
    ax.grid()
    ax.set_title(time)
    ax.set_xlabel('Time [s]')

plt.show()

# %% [markdown]
# We can see, that there is an outlier w.r.t. to the train time.

# %%
data[data['train_time'] > 10000]
# Out:
#          train_time  forecast_time         MAE           MSE          RMSE
# 27920  28655.271598       0.262712  850909.875  1.127550e+12  1.061862e+06  \
#
#            MASE     RMSSE       MAPE      SMAPE    naming_orig   model_name
# 27920  0.927062  0.873742  65.280634  17.660116  mipt_alpha_40  LightAutoML  \
#
#       dataset_name
# 27920   mipt_alpha

# %%
data = data.drop(data[data['train_time'] > 10000].index)

# %%
# Depict quality metrics boxplots
labels = data.select_dtypes(include=np.number).columns.tolist()
labels = [l for l in labels if l not in times]
labels.remove('MAPE')
rows = 2

fig, axes = plt.subplots(nrows=rows, ncols=len(labels)//rows, figsize=(16, 6))
fig.subplots_adjust(hspace=0.4)

for ax, label in zip(axes.flatten(), labels):
    sns.boxplot(data[label], ax=ax, orient='h')
    ax.grid()
    ax.set_title(label)
    ax.set_xlabel('Value')

plt.show()

# %% [markdown]
# We decided to ignore MAPE because of the metric unstability. As we can see, MAPE metrics become ill-contitioned whenever $y_i \in U(0)$, because
# $$\text{MAPE}=100\% \times \frac{1}{n}\sum_{i=1}^{n}\frac{|y_i-\hat{y_i}|}{|y_i|},$$
#
# where:
#
# $y_i$ - time series i-th value;
#
# $\hat{y_i}$ - predicted i-th value.

# %%
# Depict time metrics boxplots in log(1+x) scale
fig, axes = plt.subplots(nrows=rows, ncols=len(labels)//rows, figsize=(16, 6))
fig.subplots_adjust(hspace=0.4)

for ax, label in zip(axes.flatten(), labels):
    sns.boxplot(np.log1p(data[label]), ax=ax, orient='h')
    ax.grid()
    ax.set_title(f'{label}')
    ax.set_xlabel('Value in log(x+1) scale')

plt.show()

# %% [markdown]
# It is obvious, that MASE and RMSSE in the $\log(x+1)$ scale highlight outliers. We have tried several threshold for MASE, RMSSE and RMSE and decided to apply the following threshold
#
# $$S=\lbrace y_i, X_i \rbrace_{i=1}^m: \forall X \in S \Rightarrow X_{\text{MASE}} \leq 6 \cap X_{\text{RMSSE}} \leq 4 \cap X_{\text{RMSE}} \leq 6\cdot10^6.$$

# %%
rmsse_th = 4
mase_th = 6
rmse_th = 6e6

outliers = len(data[(data['MASE'] > mase_th) | (data['RMSSE'] > rmsse_th) | (data['RMSE'] > rmse_th)])
print(f'Number of rows with MASE > {mase_th:.2f} or RMSSE > {rmsse_th:.2f}: {outliers}')
print(f'Outliers rate: {outliers/len(data):.2%}')
# Out:
# Number of rows with MASE > 6.00 or RMSSE > 4.00: 371
# Outliers rate: 1.02%

# %%
data[(data['MASE'] > mase_th) | (data['RMSSE'] > rmsse_th) | (data['RMSE'] > rmse_th)]
# Out:
#        train_time  forecast_time           MAE           MSE          RMSE
# 53       3.812914       4.442261  6.131524e+00  5.661726e+01  7.524444e+00  \
# 75       3.812914       4.442261  1.281847e+01  3.654213e+02  1.911600e+01
# 78       3.485261       4.376619  1.050156e+01  1.104596e+02  1.050998e+01
# 96       3.485261       4.376619  1.911140e+01  7.075344e+02  2.659952e+01
# 103      3.812914       4.442261  2.217719e+01  7.893629e+02  2.809560e+01
# ...           ...            ...           ...           ...           ...
# 34391    0.000098       0.000006  5.552962e+06  4.051247e+13  6.364941e+06
# 34427    0.000095       0.000005  7.656762e+06  7.635579e+13  8.738180e+06
# 34533    0.000091       0.000005  5.526198e+06  3.951878e+13  6.286397e+06
# 34632    0.000087       0.000005  6.103602e+06  5.177452e+13  7.195451e+06
# 34688    0.000092       0.000005  5.501363e+06  4.657955e+13  6.824922e+06
#
#                MASE         RMSSE          MAPE       SMAPE
# 53     6.131524e+09  7.524444e+09           inf   39.032561  \
# 75     7.135613e+02  8.234437e+01  1.571075e+02   25.457659
# 78     1.050156e+10  1.050998e+10           inf  100.000000
# 96     9.764479e+00  3.511760e+00  6.267861e+01   20.730352
# 103    6.116581e+00  2.549262e+00           inf   25.884894
# ...             ...           ...           ...         ...
# 34391  1.457118e+00  1.285354e+00  7.166476e+01   30.613497
# 34427  7.646467e+00  5.611784e+00  7.304923e+01   59.663522
# 34533  1.821848e+00  1.600046e+00           inf   49.245909
# 34632  2.474979e+00  1.941867e+00  2.257296e+16   32.594907
# 34688  2.773377e+00  2.499240e+00  5.705987e+01   40.336400
#
#                 naming_orig                                   model_name
# 53     danish_atm_daily_111  CatBoostAutoRegressivePipelineEtna_3lags_gl  \
# 75     danish_atm_daily_110  CatBoostAutoRegressivePipelineEtna_3lags_gl
# 78     danish_atm_daily_111  CatBoostAutoRegressivePipelineEtna_3lags_gl
# 96     danish_atm_daily_109  CatBoostAutoRegressivePipelineEtna_3lags_gl
# 103    danish_atm_daily_109  CatBoostAutoRegressivePipelineEtna_3lags_gl
# ...                     ...                                          ...
# 34391         mipt_alpha_62                                 BaselineMean
# 34427        mipt_alpha_368                                 BaselineMean
# 34533        mipt_alpha_245                                 BaselineMean
# 34632        mipt_alpha_366                                 BaselineMean
# 34688        mipt_alpha_108                                 BaselineMean
#
#            dataset_name
# 53     danish_atm_daily
# 75     danish_atm_daily
# 78     danish_atm_daily
# 96     danish_atm_daily
# 103    danish_atm_daily
# ...                 ...
# 34391        mipt_alpha
# 34427        mipt_alpha
# 34533        mipt_alpha
# 34632        mipt_alpha
# 34688        mipt_alpha
#
# [371 rows x 12 columns]

# %% [markdown]
# As the number of outliers slightly exceeds 1%, we can drop them out.

# %%
data = data.drop(data[
                 (data['MASE'] > mase_th) | 
                 (data['RMSSE'] > rmsse_th) | 
                 (data['RMSE'] > rmse_th)
                 ].index)

# %%
# Depict final metrics
labels = ['MASE', 'RMSSE', 'SMAPE']

fig, axes = plt.subplots(nrows=1, ncols=len(labels), figsize=(16, 6))
fig.subplots_adjust(hspace=0.4)

for ax, label in zip(axes.flatten(), labels):
    ax.set_xlabel('Value')
    sns.violinplot(data[label], ax=ax, orient='h')
    ax.grid()
    ax.set_title(f'{label} distribution without outliers')

plt.show()

# %%
fig = plt.figure(figsize=(16,4))
plt.hist(data['model_name'], bins=24)
plt.xticks(rotation=90); plt.grid()
plt.title('Model classes distribution without outliers')
plt.show()

# %% [markdown]
# ### Correlated values handling
# Now, let's look at metrics correlation and drop out the correlated ones.
#
# NB: all the correlation matrix below contains **absolute** correlation value, thus the sign of linear dependence is not accounted for.

# %%
metrics = data.select_dtypes(include=np.number).columns.tolist()
np.abs(data[metrics].corr()).style.format("{:.2f}").background_gradient(cmap='Reds', high=1.01)
# Out:
# <style type="text/css">
# #T_a9759_row0_col0, #T_a9759_row1_col1, #T_a9759_row2_col2, #T_a9759_row3_col3, #T_a9759_row4_col4, #T_a9759_row5_col5, #T_a9759_row6_col6, #T_a9759_row7_col7, #T_a9759_row8_col8 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_a9759_row0_col1, #T_a9759_row1_col0, #T_a9759_row1_col6, #T_a9759_row6_col1 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_a9759_row0_col2, #T_a9759_row0_col4, #T_a9759_row0_col6, #T_a9759_row1_col8, #T_a9759_row3_col0, #T_a9759_row6_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_a9759_row0_col3, #T_a9759_row0_col7, #T_a9759_row0_col8, #T_a9759_row1_col7, #T_a9759_row5_col7, #T_a9759_row6_col7, #T_a9759_row7_col0, #T_a9759_row7_col1, #T_a9759_row7_col2, #T_a9759_row7_col3, #T_a9759_row7_col4, #T_a9759_row7_col5, #T_a9759_row7_col6 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_a9759_row0_col5, #T_a9759_row1_col2, #T_a9759_row1_col4 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_a9759_row1_col3, #T_a9759_row2_col7, #T_a9759_row4_col7 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_a9759_row1_col5, #T_a9759_row2_col1, #T_a9759_row4_col1 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_a9759_row2_col0, #T_a9759_row3_col1, #T_a9759_row4_col0, #T_a9759_row5_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_a9759_row2_col3, #T_a9759_row3_col2 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_a9759_row2_col4, #T_a9759_row4_col2 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_a9759_row2_col5 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_a9759_row2_col6, #T_a9759_row6_col3 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_a9759_row2_col8 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_a9759_row3_col4, #T_a9759_row4_col3 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_a9759_row3_col5 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_a9759_row3_col6 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_a9759_row3_col7, #T_a9759_row8_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_a9759_row3_col8, #T_a9759_row8_col3 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_a9759_row4_col5 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_a9759_row4_col6, #T_a9759_row6_col2 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_a9759_row4_col8 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_a9759_row5_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_a9759_row5_col2 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_a9759_row5_col3 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_a9759_row5_col4 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_a9759_row5_col6, #T_a9759_row6_col5 {
#   background-color: #fc8060;
#   color: #f1f1f1;
# }
# #T_a9759_row5_col8 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_a9759_row6_col4 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_a9759_row6_col8 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_a9759_row7_col8 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_a9759_row8_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_a9759_row8_col2 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_a9759_row8_col4 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_a9759_row8_col5 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_a9759_row8_col6 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_a9759_row8_col7 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# </style>
# <table id="T_a9759">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9759_level0_col0" class="col_heading level0 col0" >train_time</th>
#       <th id="T_a9759_level0_col1" class="col_heading level0 col1" >forecast_time</th>
#       <th id="T_a9759_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_a9759_level0_col3" class="col_heading level0 col3" >MSE</th>
#       <th id="T_a9759_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_a9759_level0_col5" class="col_heading level0 col5" >MASE</th>
#       <th id="T_a9759_level0_col6" class="col_heading level0 col6" >RMSSE</th>
#       <th id="T_a9759_level0_col7" class="col_heading level0 col7" >MAPE</th>
#       <th id="T_a9759_level0_col8" class="col_heading level0 col8" >SMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9759_level0_row0" class="row_heading level0 row0" >train_time</th>
#       <td id="T_a9759_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_a9759_row0_col1" class="data row0 col1" >0.08</td>
#       <td id="T_a9759_row0_col2" class="data row0 col2" >0.07</td>
#       <td id="T_a9759_row0_col3" class="data row0 col3" >0.04</td>
#       <td id="T_a9759_row0_col4" class="data row0 col4" >0.07</td>
#       <td id="T_a9759_row0_col5" class="data row0 col5" >0.07</td>
#       <td id="T_a9759_row0_col6" class="data row0 col6" >0.04</td>
#       <td id="T_a9759_row0_col7" class="data row0 col7" >0.03</td>
#       <td id="T_a9759_row0_col8" class="data row0 col8" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_a9759_level0_row1" class="row_heading level0 row1" >forecast_time</th>
#       <td id="T_a9759_row1_col0" class="data row1 col0" >0.08</td>
#       <td id="T_a9759_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_a9759_row1_col2" class="data row1 col2" >0.11</td>
#       <td id="T_a9759_row1_col3" class="data row1 col3" >0.07</td>
#       <td id="T_a9759_row1_col4" class="data row1 col4" >0.11</td>
#       <td id="T_a9759_row1_col5" class="data row1 col5" >0.10</td>
#       <td id="T_a9759_row1_col6" class="data row1 col6" >0.08</td>
#       <td id="T_a9759_row1_col7" class="data row1 col7" >0.03</td>
#       <td id="T_a9759_row1_col8" class="data row1 col8" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_a9759_level0_row2" class="row_heading level0 row2" >MAE</th>
#       <td id="T_a9759_row2_col0" class="data row2 col0" >0.07</td>
#       <td id="T_a9759_row2_col1" class="data row2 col1" >0.11</td>
#       <td id="T_a9759_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_a9759_row2_col3" class="data row2 col3" >0.93</td>
#       <td id="T_a9759_row2_col4" class="data row2 col4" >0.99</td>
#       <td id="T_a9759_row2_col5" class="data row2 col5" >0.29</td>
#       <td id="T_a9759_row2_col6" class="data row2 col6" >0.44</td>
#       <td id="T_a9759_row2_col7" class="data row2 col7" >0.06</td>
#       <td id="T_a9759_row2_col8" class="data row2 col8" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_a9759_level0_row3" class="row_heading level0 row3" >MSE</th>
#       <td id="T_a9759_row3_col0" class="data row3 col0" >0.04</td>
#       <td id="T_a9759_row3_col1" class="data row3 col1" >0.07</td>
#       <td id="T_a9759_row3_col2" class="data row3 col2" >0.93</td>
#       <td id="T_a9759_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_a9759_row3_col4" class="data row3 col4" >0.92</td>
#       <td id="T_a9759_row3_col5" class="data row3 col5" >0.28</td>
#       <td id="T_a9759_row3_col6" class="data row3 col6" >0.45</td>
#       <td id="T_a9759_row3_col7" class="data row3 col7" >0.04</td>
#       <td id="T_a9759_row3_col8" class="data row3 col8" >0.31</td>
#     </tr>
#     <tr>
#       <th id="T_a9759_level0_row4" class="row_heading level0 row4" >RMSE</th>
#       <td id="T_a9759_row4_col0" class="data row4 col0" >0.07</td>
#       <td id="T_a9759_row4_col1" class="data row4 col1" >0.11</td>
#       <td id="T_a9759_row4_col2" class="data row4 col2" >0.99</td>
#       <td id="T_a9759_row4_col3" class="data row4 col3" >0.92</td>
#       <td id="T_a9759_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_a9759_row4_col5" class="data row4 col5" >0.24</td>
#       <td id="T_a9759_row4_col6" class="data row4 col6" >0.42</td>
#       <td id="T_a9759_row4_col7" class="data row4 col7" >0.06</td>
#       <td id="T_a9759_row4_col8" class="data row4 col8" >0.26</td>
#     </tr>
#     <tr>
#       <th id="T_a9759_level0_row5" class="row_heading level0 row5" >MASE</th>
#       <td id="T_a9759_row5_col0" class="data row5 col0" >0.07</td>
#       <td id="T_a9759_row5_col1" class="data row

# %% [markdown]
# Let's drop out MAE and MSE, which correlate to the RMSE. Repeat the same with MASE and MAPE.

# %%
data = data.drop(['MAE', 'MSE', 'MASE', 'MAPE'], axis=1)

# %%
metrics = data.select_dtypes(include=np.number).columns.tolist()
np.abs(data[metrics].corr()).style.format("{:.2f}").background_gradient(cmap='Reds', high=1.01)
# Out:
# <style type="text/css">
# #T_d440e_row0_col0, #T_d440e_row1_col1, #T_d440e_row2_col2, #T_d440e_row3_col3, #T_d440e_row4_col4 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_d440e_row0_col1, #T_d440e_row2_col0, #T_d440e_row3_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_d440e_row0_col2, #T_d440e_row0_col3, #T_d440e_row0_col4, #T_d440e_row3_col0, #T_d440e_row4_col0, #T_d440e_row4_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_d440e_row1_col0, #T_d440e_row1_col2, #T_d440e_row1_col3 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_d440e_row1_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_d440e_row2_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_d440e_row2_col3 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_d440e_row2_col4 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_d440e_row3_col2 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_d440e_row3_col4, #T_d440e_row4_col3 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_d440e_row4_col2 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# </style>
# <table id="T_d440e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d440e_level0_col0" class="col_heading level0 col0" >train_time</th>
#       <th id="T_d440e_level0_col1" class="col_heading level0 col1" >forecast_time</th>
#       <th id="T_d440e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d440e_level0_col3" class="col_heading level0 col3" >RMSSE</th>
#       <th id="T_d440e_level0_col4" class="col_heading level0 col4" >SMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d440e_level0_row0" class="row_heading level0 row0" >train_time</th>
#       <td id="T_d440e_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_d440e_row0_col1" class="data row0 col1" >0.08</td>
#       <td id="T_d440e_row0_col2" class="data row0 col2" >0.07</td>
#       <td id="T_d440e_row0_col3" class="data row0 col3" >0.04</td>
#       <td id="T_d440e_row0_col4" class="data row0 col4" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_d440e_level0_row1" class="row_heading level0 row1" >forecast_time</th>
#       <td id="T_d440e_row1_col0" class="data row1 col0" >0.08</td>
#       <td id="T_d440e_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_d440e_row1_col2" class="data row1 col2" >0.11</td>
#       <td id="T_d440e_row1_col3" class="data row1 col3" >0.08</td>
#       <td id="T_d440e_row1_col4" class="data row1 col4" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_d440e_level0_row2" class="row_heading level0 row2" >RMSE</th>
#       <td id="T_d440e_row2_col0" class="data row2 col0" >0.07</td>
#       <td id="T_d440e_row2_col1" class="data row2 col1" >0.11</td>
#       <td id="T_d440e_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_d440e_row2_col3" class="data row2 col3" >0.42</td>
#       <td id="T_d440e_row2_col4" class="data row2 col4" >0.26</td>
#     </tr>
#     <tr>
#       <th id="T_d440e_level0_row3" class="row_heading level0 row3" >RMSSE</th>
#       <td id="T_d440e_row3_col0" class="data row3 col0" >0.04</td>
#       <td id="T_d440e_row3_col1" class="data row3 col1" >0.08</td>
#       <td id="T_d440e_row3_col2" class="data row3 col2" >0.42</td>
#       <td id="T_d440e_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_d440e_row3_col4" class="data row3 col4" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_d440e_level0_row4" class="row_heading level0 row4" >SMAPE</th>
#       <td id="T_d440e_row4_col0" class="data row4 col0" >0.04</td>
#       <td id="T_d440e_row4_col1" class="data row4 col1" >0.05</td>
#       <td id="T_d440e_row4_col2" class="data row4 col2" >0.26</td>
#       <td id="T_d440e_row4_col3" class="data row4 col3" >0.48</td>
#       <td id="T_d440e_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We decided to introudce cumulative normalized metric, which can be calculated as follow:
#
# $$CM(X)=\frac{1}{\sum_{i=1}^{n}\omega_i}\sum_{i=1}^{n}\omega_i\exp(-x_i),$$
#
# where:
#
# $X=(x_1,...,x_n)$ - metrics vector;
#
# $\omega_1,...,\omega_n$ - metrics weights.

# %%
def cumulative_metric(metrics, time, time_weight=0.15):
    result = np.zeros(time.shape)
    # Add and normalize every metric with exp(-x)
    for metric in metrics:
        result = result + np.exp(-metric)
    # Add the weighted time metric
    result = result + time_weight*np.exp(-time)
    # Normalize result w.r.t. metrics weight 
    result = result / (len(metrics)+time_weight)
    return result

data['CM'] = cumulative_metric([data['RMSE'], data['RMSSE'], data['SMAPE']], 
                                       data['train_time'] + data['forecast_time'])

# %%
metrics = data.select_dtypes(include=np.number).columns.tolist()
np.abs(data[metrics].corr()).style.format("{:.2f}").background_gradient(cmap='Reds', high=1.01)
# Out:
# <style type="text/css">
# #T_151d1_row0_col0, #T_151d1_row1_col1, #T_151d1_row2_col2, #T_151d1_row3_col3, #T_151d1_row4_col4, #T_151d1_row5_col5 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_151d1_row0_col1, #T_151d1_row2_col0, #T_151d1_row3_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_151d1_row0_col2, #T_151d1_row0_col3, #T_151d1_row0_col4, #T_151d1_row0_col5, #T_151d1_row3_col0, #T_151d1_row4_col0, #T_151d1_row4_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_151d1_row1_col0, #T_151d1_row1_col2, #T_151d1_row1_col3 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_151d1_row1_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_151d1_row1_col5, #T_151d1_row5_col0 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_151d1_row2_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_151d1_row2_col3 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_151d1_row2_col4 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_151d1_row2_col5, #T_151d1_row5_col4 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_151d1_row3_col2 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_151d1_row3_col4, #T_151d1_row4_col3 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_151d1_row3_col5 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_151d1_row4_col2 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_151d1_row4_col5 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_151d1_row5_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_151d1_row5_col2 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_151d1_row5_col3 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_151d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_151d1_level0_col0" class="col_heading level0 col0" >train_time</th>
#       <th id="T_151d1_level0_col1" class="col_heading level0 col1" >forecast_time</th>
#       <th id="T_151d1_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_151d1_level0_col3" class="col_heading level0 col3" >RMSSE</th>
#       <th id="T_151d1_level0_col4" class="col_heading level0 col4" >SMAPE</th>
#       <th id="T_151d1_level0_col5" class="col_heading level0 col5" >CM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_151d1_level0_row0" class="row_heading level0 row0" >train_time</th>
#       <td id="T_151d1_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_151d1_row0_col1" class="data row0 col1" >0.08</td>
#       <td id="T_151d1_row0_col2" class="data row0 col2" >0.07</td>
#       <td id="T_151d1_row0_col3" class="data row0 col3" >0.04</td>
#       <td id="T_151d1_row0_col4" class="data row0 col4" >0.04</td>
#       <td id="T_151d1_row0_col5" class="data row0 col5" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_151d1_level0_row1" class="row_heading level0 row1" >forecast_time</th>
#       <td id="T_151d1_row1_col0" class="data row1 col0" >0.08</td>
#       <td id="T_151d1_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_151d1_row1_col2" class="data row1 col2" >0.11</td>
#       <td id="T_151d1_row1_col3" class="data row1 col3" >0.08</td>
#       <td id="T_151d1_row1_col4" class="data row1 col4" >0.05</td>
#       <td id="T_151d1_row1_col5" class="data row1 col5" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_151d1_level0_row2" class="row_heading level0 row2" >RMSE</th>
#       <td id="T_151d1_row2_col0" class="data row2 col0" >0.07</td>
#       <td id="T_151d1_row2_col1" class="data row2 col1" >0.11</td>
#       <td id="T_151d1_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_151d1_row2_col3" class="data row2 col3" >0.42</td>
#       <td id="T_151d1_row2_col4" class="data row2 col4" >0.26</td>
#       <td id="T_151d1_row2_col5" class="data row2 col5" >0.46</td>
#     </tr>
#     <tr>
#       <th id="T_151d1_level0_row3" class="row_heading level0 row3" >RMSSE</th>
#       <td id="T_151d1_row3_col0" class="data row3 col0" >0.04</td>
#       <td id="T_151d1_row3_col1" class="data row3 col1" >0.08</td>
#       <td id="T_151d1_row3_col2" class="data row3 col2" >0.42</td>
#       <td id="T_151d1_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_151d1_row3_col4" class="data row3 col4" >0.48</td>
#       <td id="T_151d1_row3_col5" class="data row3 col5" >0.89</td>
#     </tr>
#     <tr>
#       <th id="T_151d1_level0_row4" class="row_heading level0 row4" >SMAPE</th>
#       <td id="T_151d1_row4_col0" class="data row4 col0" >0.04</td>
#       <td id="T_151d1_row4_col1" class="data row4 col1" >0.05</td>
#       <td id="T_151d1_row4_col2" class="data row4 col2" >0.26</td>
#       <td id="T_151d1_row4_col3" class="data row4 col3" >0.48</td>
#       <td id="T_151d1_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_151d1_row4_col5" class="data row4 col5" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_151d1_level0_row5" class="row_heading level0 row5" >CM</th>
#       <td id="T_151d1_row5_col0" class="data row5 col0" >0.09</td>
#       <td id="T_151d1_row5_col1" class="data row5 col1" >0.15</td>
#       <td id="T_151d1_row5_col2" class="data row5 col2" >0.46</td>
#       <td id="T_151d1_row5_col3" class="data row5 col3" >0.89</td>
#       <td id="T_151d1_row5_col4" class="data row5 col4" >0.43</td>
#       <td id="T_151d1_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Depicts final metrics distribution
labels = ['RMSE', 'RMSSE', 'SMAPE', 'CM']
rows = 2

fig, axes = plt.subplots(nrows=rows, ncols=len(labels)//rows, figsize=(16, 6))
fig.subplots_adjust(hspace=0.4)

for ax, label in zip(axes.flatten(), labels):
    ax.set_xlabel('Value')
    sns.violinplot(data[label], ax=ax, orient='h')
    ax.grid()
    ax.set_title(f'{label} distribution without outliers')
    

plt.show()
fig.savefig('./output/final_metrics', dpi=300)

# %%
data.to_csv('./data/preprocessed_res.csv')
