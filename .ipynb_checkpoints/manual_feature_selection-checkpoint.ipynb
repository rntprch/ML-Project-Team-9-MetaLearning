# %%
# !pip install tsfeatures
# Out:
# Requirement already satisfied: tsfeatures in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (0.4.5)
# Requirement already satisfied: antropy>=0.1.4 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from tsfeatures) (0.1.6)
# Requirement already satisfied: arch>=4.11 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from tsfeatures) (6.3.0)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from tsfeatures) (2.0.1)
# Requirement already satisfied: scikit-learn>=0.23.1 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from tsfeatures) (1.4.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from tsfeatures) (0.14.1)
# Requirement already satisfied: supersmoother>=0.4 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from tsfeatures) (0.4)
# Requirement already satisfied: numpy in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from antropy>=0.1.4->tsfeatures) (1.24.3)
# Requirement already satisfied: scipy in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from antropy>=0.1.4->tsfeatures) (1.10.1)
# Requirement already satisfied: numba>=0.57 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from antropy>=0.1.4->tsfeatures) (0.59.0)
# Requirement already satisfied: stochastic in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from antropy>=0.1.4->tsfeatures) (0.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.0.5->tsfeatures) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.0.5->tsfeatures) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.0.5->tsfeatures) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.23.1->tsfeatures) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.23.1->tsfeatures) (3.2.0)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from statsmodels>=0.13.2->tsfeatures) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from statsmodels>=0.13.2->tsfeatures) (23.1)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from numba>=0.57->antropy>=0.1.4->tsfeatures) (0.42.0)
# Requirement already satisfied: six in c:\users\mekor\appdata\local\programs\python\python311\lib\site-packages (from patsy>=0.5.4->statsmodels>=0.13.2->tsfeatures) (1.16.0)

# %%
import pandas as pd
import tsfeatures as tf
from tqdm.notebook import tqdm
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
# Setting input and output paths for convinient cycle iterations
input_list = [ 'data\danish_atm_daily.csv',
                'data\mipt_alpha.csv',
                'data/nn5.csv']
output_list = ['manual_features\danish_manual_features.csv',
               'manual_features\mipt_manual_features.csv',
               'manual_features/nn_manual_features.csv']

# %%
def features_extr(df, column):
    
    '''
    Extracting features

    Args:
        df (pd.DataFrame): DataFrame from where extract features
        column (str): Column wich correspond one time series
    '''
    
    feat_list = [
        tf.holt_parameters(df[column].values),
        tf.count_entropy(df[column].values),
        tf.crossing_points(df[column].values),
        tf.entropy(df[column].values),
        tf.flat_spots(df[column].values),
        tf.frequency(df[column].values),
        tf.heterogeneity(df[column].values),
        tf.guerrero(df[column].values),
        tf.hurst(df[column].values),
        tf.hw_parameters(df[column].values),
        tf.intervals(df[column].values),
        tf.lumpiness(df[column].values),
        tf.acf_features(df[column].values),
        tf.arch_stat(df[column].values),
        tf.pacf_features(df[column].values),
        tf.sparsity(df[column].values),
        tf.stability(df[column].values),
        tf.stl_features(df[column].values),
        tf.unitroot_kpss(df[column].values),
        tf.unitroot_pp(df[column].values)
    ]
    return feat_list

# %%
for inp, out in tqdm(zip(input_list, output_list)):
    
    # Read data
    df = pd.read_csv(inp)
    
    # Initialize an empty DataFrame to accumulate the results.
    df_out = pd.DataFrame()

    # Iterate over each column in the original DataFrame.
    for column in tqdm(df.columns):
               
        # Extract features for the current column.
        extracted_features = features_extr(df, column)
        
        # Combine all extracted feature dictionaries into a single dictionary.
        combined_features = {}
        for feature_dict in extracted_features:
            combined_features.update(feature_dict)
        
        # Create a DataFrame from the combined features.
        temp_df = pd.DataFrame.from_dict(combined_features, orient='index', columns=[column])
        
        # Concatenate temp_df to df_out horizontally.
        df_out = pd.concat([df_out, temp_df], axis=1, join='outer')
    
    # Drop all NaNs
    df_out.dropna(inplace=True)
    
    # Save to file
    df_out.to_csv(out)
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/113 [00:00<?, ?it/s]
#   0%|          | 0/650 [00:00<?, ?it/s]
#   0%|          | 0/111 [00:00<?, ?it/s]

# %%
# Printing features
for i in output_list:
    df = pd.read_csv(i, index_col=0)
    print(i)
    print(df.columns)
    print(f"Quantity of features: {len(df.columns)}")
    print('\n')
# Out:
# manual_features\danish_manual_features.csv
# Index(['danish_atm_daily_0', 'danish_atm_daily_1', 'danish_atm_daily_10',
#        'danish_atm_daily_100', 'danish_atm_daily_101', 'danish_atm_daily_102',
#        'danish_atm_daily_103', 'danish_atm_daily_104', 'danish_atm_daily_105',
#        'danish_atm_daily_106',
#        ...
#        'danish_atm_daily_90', 'danish_atm_daily_91', 'danish_atm_daily_92',
#        'danish_atm_daily_93', 'danish_atm_daily_94', 'danish_atm_daily_95',
#        'danish_atm_daily_96', 'danish_atm_daily_97', 'danish_atm_daily_98',
#        'danish_atm_daily_99'],
#       dtype='object', length=113)
# Quantity of features: 113
#
#
# manual_features\mipt_manual_features.csv
# Index(['mipt_alpha_0', 'mipt_alpha_1', 'mipt_alpha_10', 'mipt_alpha_100',
#        'mipt_alpha_101', 'mipt_alpha_102', 'mipt_alpha_103', 'mipt_alpha_104',
#        'mipt_alpha_105', 'mipt_alpha_106',
#        ...
#        'mipt_alpha_90', 'mipt_alpha_91', 'mipt_alpha_92', 'mipt_alpha_93',
#        'mipt_alpha_94', 'mipt_alpha_95', 'mipt_alpha_96', 'mipt_alpha_97',
#        'mipt_alpha_98', 'mipt_alpha_99'],
#       dtype='object', length=650)
# Quantity of features: 650
#
#
# manual_features/nn_manual_features.csv
# Index(['nn5_0', 'nn5_1', 'nn5_10', 'nn5_100', 'nn5_101', 'nn5_102', 'nn5_103',
#        'nn5_104', 'nn5_105', 'nn5_106',
#        ...
#        'nn5_90', 'nn5_91', 'nn5_92', 'nn5_93', 'nn5_94', 'nn5_95', 'nn5_96',
#        'nn5_97', 'nn5_98', 'nn5_99'],
#       dtype='object', length=111)
# Quantity of features: 111

# %%
# Transposing data
for i in output_list:
    df = pd.read_csv(i, index_col=0)
    df = df.T
    df.to_csv(i)

# %%
# Checking how data look
for i in output_list:
    df = pd.read_csv(i, index_col=0)
    display(df.head(2))
# Out:
#                        alpha     beta  count_entropy  crossing_points
# danish_atm_daily_0  0.165744  0.00987 -171289.625528            115.0  \
# danish_atm_daily_1  0.169660  0.03005 -186506.124217             67.0
#
#                      entropy  flat_spots  frequency  intervals_mean
# danish_atm_daily_0  0.832942         6.0        1.0       59.400000  \
# danish_atm_daily_1  0.838796       108.0        1.0      100.666667
#
#                     lumpiness   arch_lm  sparsity  stability  nperiods
# danish_atm_daily_0   0.003311  0.271016  0.026230   0.008920       0.0  \
# danish_atm_daily_1   0.001346  0.000178  0.009836   0.001621       0.0
#
#                     seasonal_period     trend         spike  linearity
# danish_atm_daily_0              1.0  0.048930  2.149307e-07  -0.132583  \
# danish_atm_daily_1              1.0  0.050821  8.532189e-08   0.174946
#
#                     curvature
# danish_atm_daily_0   0.238538
# danish_atm_daily_1  -0.168956
#                  alpha      beta  count_entropy  crossing_points   entropy
# mipt_alpha_0  0.146429  0.036607  -3.344339e+10            255.0  0.750951  \
# mipt_alpha_1  0.217143  0.032571  -1.572763e+10            162.0  0.578434
#
#               flat_spots  frequency     hurst  intervals_mean  lumpiness
# mipt_alpha_0         5.0        1.0  0.787643          671.00   0.000000  \
# mipt_alpha_1       176.0        1.0  1.088826          120.75   0.002706
#
#                arch_lm  sparsity  stability  nperiods  seasonal_period
# mipt_alpha_0  1.000000  0.000000   0.000000       0.0              1.0  \
# mipt_alpha_1  0.950701  0.280179   0.190769       0.0              1.0
#
#                  trend         spike     linearity     curvature
# mipt_alpha_0  0.000000  0.000000e+00  3.330669e-16  3.219647e-15
# mipt_alpha_1  0.877022  2.298643e-08  5.339229e+00  6.874725e-01
#               alpha          beta  count_entropy  crossing_points   entropy
# nn5_0  1.537202e-08  1.782918e-09  -68475.870483            229.0  0.705705  \
# nn5_1  1.490116e-08  1.736061e-10  -36241.351149            269.0  0.772642
#
#        flat_spots  frequency     hurst  intervals_mean  intervals_sd  ...
# nn5_0         5.0        1.0  0.865866       37.368421     37.987148  ...  \
# nn5_1         7.0        1.0  0.634561       44.437500     36.029560  ...
#
#        nperiods  seasonal_period     trend         spike  linearity
# nn5_0       0.0              1.0  0.008541  4.548068e-08   0.069356  \
# nn5_1       0.0              1.0  0.013273  4.319773e-08   0.012371
#
#        curvature    e_acf1   e_acf10  unitroot_kpss  unitroot_pp
# nn5_0   0.092808  0.109844  0.042532       0.073708  -635.596768
# nn5_1   0.073767  0.218461  0.063091       0.128528  -543.997661
#
# [2 rows x 33 columns]

# %%
# Cheking for NaNs
for i in output_list:
    print(f'NaNs quantity in {i}: {np.sum(pd.read_csv(i).isna().sum())}')
    print('\n')
# Out:
# NaNs quantity in manual_features\danish_manual_features.csv: 0
#
#
# NaNs quantity in manual_features\mipt_manual_features.csv: 0
#
#
# NaNs quantity in manual_features/nn_manual_features.csv: 0
