# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('data/preprocessed_train.csv')
test = pd.read_csv('data/preprocessed_test.csv')
features_danish = pd.read_csv('manual_features\danish_manual_features.csv')
features_mipt = pd.read_csv('manual_features\mipt_manual_features.csv')
features_nn = pd.read_csv('manual_features/nn_manual_features.csv')

# %%
print(f'features_danish {features_danish.columns}, lenght: {len(features_danish.columns)}')
print(f'features_mipt {features_mipt.columns}, lenght: {len(features_mipt.columns)}')
print(f'features_nn {features_nn.columns} lenght: {len(features_nn.columns)}')
# Out:
# features_danish Index(['Unnamed: 0', 'alpha', 'beta', 'count_entropy', 'crossing_points',
#        'entropy', 'flat_spots', 'frequency', 'intervals_mean', 'lumpiness',
#        'arch_lm', 'sparsity', 'stability', 'nperiods', 'seasonal_period',
#        'trend', 'spike', 'linearity', 'curvature'],
#       dtype='object'), lenght: 19
# features_mipt Index(['Unnamed: 0', 'alpha', 'beta', 'count_entropy', 'crossing_points',
#        'entropy', 'flat_spots', 'frequency', 'hurst', 'intervals_mean',
#        'lumpiness', 'arch_lm', 'sparsity', 'stability', 'nperiods',
#        'seasonal_period', 'trend', 'spike', 'linearity', 'curvature'],
#       dtype='object'), lenght: 20
# features_nn Index(['Unnamed: 0', 'alpha', 'beta', 'count_entropy', 'crossing_points',
#        'entropy', 'flat_spots', 'frequency', 'hurst', 'intervals_mean',
#        'intervals_sd', 'lumpiness', 'x_acf1', 'x_acf10', 'diff1_acf1',
#        'diff1_acf10', 'diff2_acf1', 'diff2_acf10', 'arch_lm', 'x_pacf5',
#        'diff1x_pacf5', 'diff2x_pacf5', 'sparsity', 'stability', 'nperiods',
#        'seasonal_period', 'trend', 'spike', 'linearity', 'curvature', 'e_acf1',
#        'e_acf10', 'unitroot_kpss', 'unitroot_pp'],
#       dtype='object') lenght: 34

# %%
# Checking difference in features
unique_list3 = set(features_nn.columns) - (set(features_danish.columns) | set(features_mipt.columns))
# Manually adding "hurst", because it wasn't added during logical operation
unique_list3.update({'hurst'})

# %%
# Dropping different columns
for df, name in zip([features_danish, features_mipt, features_nn], ['features_danish', 'features_mipt', 'features_nn']):
    for col in unique_list3:
        if col in df.columns:
            df.drop(col, axis=1, inplace=True)
            print(f'Column {col} dropped from {name}')
# Out:
# Column hurst dropped from features_mipt
# Column diff2_acf10 dropped from features_nn
# Column e_acf1 dropped from features_nn
# Column x_acf10 dropped from features_nn
# Column diff1_acf1 dropped from features_nn
# Column diff1_acf10 dropped from features_nn
# Column x_acf1 dropped from features_nn
# Column diff1x_pacf5 dropped from features_nn
# Column intervals_sd dropped from features_nn
# Column e_acf10 dropped from features_nn
# Column unitroot_pp dropped from features_nn
# Column diff2x_pacf5 dropped from features_nn
# Column x_pacf5 dropped from features_nn
# Column hurst dropped from features_nn
# Column unitroot_kpss dropped from features_nn
# Column diff2_acf1 dropped from features_nn

# %%
print(f'features_danish {features_danish.columns}, lenght: {len(features_danish.columns)}')
print(f'features_mipt {features_mipt.columns}, lenght: {len(features_mipt.columns)}')
print(f'features_nn {features_nn.columns} lenght: {len(features_nn.columns)}')
# Out:
# features_danish Index(['Unnamed: 0', 'alpha', 'beta', 'count_entropy', 'crossing_points',
#        'entropy', 'flat_spots', 'frequency', 'intervals_mean', 'lumpiness',
#        'arch_lm', 'sparsity', 'stability', 'nperiods', 'seasonal_period',
#        'trend', 'spike', 'linearity', 'curvature'],
#       dtype='object'), lenght: 19
# features_mipt Index(['Unnamed: 0', 'alpha', 'beta', 'count_entropy', 'crossing_points',
#        'entropy', 'flat_spots', 'frequency', 'intervals_mean', 'lumpiness',
#        'arch_lm', 'sparsity', 'stability', 'nperiods', 'seasonal_period',
#        'trend', 'spike', 'linearity', 'curvature'],
#       dtype='object'), lenght: 19
# features_nn Index(['Unnamed: 0', 'alpha', 'beta', 'count_entropy', 'crossing_points',
#        'entropy', 'flat_spots', 'frequency', 'intervals_mean', 'lumpiness',
#        'arch_lm', 'sparsity', 'stability', 'nperiods', 'seasonal_period',
#        'trend', 'spike', 'linearity', 'curvature'],
#       dtype='object') lenght: 19

# %%
# Concating features
features = pd.concat([features_danish, features_mipt, features_nn], axis=0)
print(f'NaNs in features {np.sum(features.isna().sum())}')
# Out:
# NaNs in features 0

# %%
# Sorting features
features_sorted = features.sort_values(by='naming_orig', axis=0, ascending=True)

# %%
# Dropping Unamed: 0 column
train.drop(train.columns[0], inplace=True, axis=1)
test.drop(test.columns[0], inplace=True, axis=1)

# %%
# Setting index and sorting
#train.set_index('naming_orig', inplace=True)
train_sorted = train.sort_values(by='naming_orig', axis=0, ascending=True)
#test.set_index('naming_orig', inplace=True)
test_sorted = test.sort_values(by='naming_orig', axis=0, ascending=True)

# %%
features
# Out:
#                Unnamed: 0         alpha      beta  count_entropy
# 0      danish_atm_daily_0  1.657438e-01  0.009870 -171289.625528  \
# 1      danish_atm_daily_1  1.696602e-01  0.030050 -186506.124217
# 2     danish_atm_daily_10  3.349371e-01  0.000108 -126910.211280
# 3    danish_atm_daily_100  1.490116e-08  0.000000  -47743.428902
# 4    danish_atm_daily_101  8.013167e-02  0.000000  -84083.905902
# ..                    ...           ...       ...            ...
# 106                nn5_95  4.765324e-02  0.000000  -49099.855304
# 107                nn5_96  1.450781e-01  0.000000  -27296.508481
# 108                nn5_97  2.427340e-02  0.000000  -46489.182478
# 109                nn5_98  6.303822e-02  0.000000  -27547.457264
# 110                nn5_99  3.327321e-02  0.000000  -26471.830411
#
#      crossing_points   entropy  flat_spots  frequency  intervals_mean
# 0              115.0  0.832942         6.0        1.0       59.400000  \
# 1               67.0  0.838796       108.0        1.0      100.666667
# 2              101.0  0.865232        10.0        1.0       31.111111
# 3              114.0  0.826302         6.0        1.0       32.222222
# 4               53.0  0.782084       126.0        1.0       49.500000
# ..               ...       ...         ...        ...             ...
# 106            277.0  0.705937         4.0        1.0       50.857143
# 107            246.0  0.699711         6.0        1.0       41.882353
# 108            298.0  0.724865         5.0        1.0       59.666667
# 109            233.0  0.772084         5.0        1.0       47.533333
# 110            243.0  0.746520         5.0        1.0       65.272727
#
#      lumpiness   arch_lm  sparsity  stability  nperiods  seasonal_period
# 0     0.003311  0.271016  0.026230   0.008920       0.0              1.0  \
# 1     0.001346  0.000178  0.009836   0.001621       0.0              1.0
# 2     0.008169  0.436217  0.081967   0.031092       0.0              1.0
# 3     0.006076  0.231757  0.049180   0.010172       0.0              1.0
# 4     0.003420  0.207726  0.026230   0.004782       0.0              1.0
# ..         ...       ...       ...        ...       ...              ...
# 106   0.003220  0.122940  0.025992   0.004174       0.0              1.0
# 107   0.002516  0.057562  0.025992   0.003063       0.0              1.0
# 108   0.002378  0.090045  0.020520   0.003044       0.0              1.0
# 109   0.002795  0.064954  0.024624   0.003550       0.0              1.0
# 110   0.001856  0.069421  0.017784   0.002317       0.0              1.0
#
#         trend         spike  linearity  curvature
# 0    0.048930  2.149307e-07  -0.132583   0.238538
# 1    0.050821  8.532189e-08   0.174946  -0.168956
# 2    0.409299  2.016390e-07  -0.086137  -0.062198
# 3    0.043788  3.614013e-07  -0.127912   0.437014
# 4    0.055317  2.114193e-07   0.109905   0.301157
# ..        ...           ...        ...        ...
# 106  0.016721  4.094732e-08   0.042712   0.128781
# 107  0.007398  4.184013e-08   0.078892   0.067768
# 108  0.021053  3.280696e-08  -0.073337   0.130115
# 109  0.011235  3.969010e-08  -0.013026   0.072570
# 110  0.008847  2.989207e-08  -0.056639   0.058085
#
# [874 rows x 19 columns]

# %%
# Features to drop for train and test data
drop_from_train = list(set(features.index)-set(train_sorted.index))
print(f'Features to drop fetures list for train {drop_from_train}')
drop_from_test = list(set(features.index)-set(test_sorted.index))
print(f'Features to drop fetures list for train {drop_from_test}')
# Out:
# Features to drop fetures list for train []
# Features to drop fetures list for train []

# %%
# Dropping values from features
features_train = features.drop(drop_from_train, axis=0)
features_test = features.drop(drop_from_test, axis=0)

# %%
# Concatinating data
train_conc = pd.concat([features_train, train_sorted], axis=1)
test_conc = pd.concat([features_test, test_sorted], axis=1)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[80], line 2
#       1 # Concatinating data
# ----> 2 train_conc = pd.concat([features_train, train_sorted], axis=1)
#       3 test_conc = pd.concat([features_test, test_sorted], axis=1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\concat.py:385, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     370     copy = False
#     372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#    (...)
#     382     sort=sort,
#     383 )
# --> 385 return op.get_result()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\concat.py:612, in _Concatenator.get_result(self)
#     610         obj_labels = obj.axes[1 - ax]
#     611         if not new_labels.equals(obj_labels):
# --> 612             indexers[ax] = obj_labels.get_indexer(new_labels)
#     614     mgrs_indexers.append((obj._mgr, indexers))
#     616 new_data = concatenate_managers(
#     617     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     618 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3731, in Index.get_indexer(self, target, method, limit, tolerance)
#    3728 self._check_indexing_method(method, limit, tolerance)
#    3730 if not self._index_as_unique:
# -> 3731     raise InvalidIndexError(self._requires_unique_msg)
#    3733 if len(target) == 0:
#    3734     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
# Cheking NaNs
print(f'NaNs in train set {np.sum(train_conc.isna().sum())}')
print(f'NaNs in test set {np.sum(test_conc.isna().sum())}')

# %%
# Saving files
test_conc.to_csv('data/ready_test.csv')
train_conc.to_csv('data/ready_train.csv')
